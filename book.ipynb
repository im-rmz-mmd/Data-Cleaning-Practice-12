# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Book.csv')
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                   Germany  Carretera           NaN
# 1          Government                   Germany      Paseo           NaN
# 2          Government                    Canada      Paseo           NaN
# 3          Government                   Germany      Paseo           NaN
# 4          Government                   Germany       Velo           NaN
# ..                ...                       ...        ...           ...
# 695         Midmarket                    Canada      Paseo          High
# 696         Midmarket                    Canada      Paseo          High
# 697        Enterprise                   Germany      Paseo          High
# 698         Midmarket                   Germany      Paseo          High
# 699  Channel Partners  United States of America      Paseo          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df = df.drop(columns = {'Segment', 'Month Number', 'Month Name', 'Year', 'Units Sold', 'Gross Sales', 'COGS'})
df = df.drop_duplicates()
df = df.dropna()
df
# Out:
#                       Country    Product Discount Band  Manufacturing Price  \
# 7                      Mexico  Carretera           Low                    3
# 8                      Mexico  Carretera           Low                    3
# 9                      France  Carretera           Low                    3
# 10                     France      Paseo           Low                   10
# 11                     Canada        VTT           Low                  250
# ..                        ...        ...           ...                  ...
# 695                    Canada      Paseo          High                   10
# 696                    Canada      Paseo          High                   10
# 697                   Germany      Paseo          High                   10
# 698                   Germany      Paseo          High                   10
# 699  United States of America      Paseo          High                   10
#
# ...

# %%
df = df.rename(columns = {' Sales' : 'Sales'})
df
# Out:
#                       Country    Product Discount Band  Manufacturing Price  \
# 7                      Mexico  Carretera           Low                    3
# 8                      Mexico  Carretera           Low                    3
# 9                      France  Carretera           Low                    3
# 10                     France      Paseo           Low                   10
# 11                     Canada        VTT           Low                  250
# ..                        ...        ...           ...                  ...
# 695                    Canada      Paseo          High                   10
# 696                    Canada      Paseo          High                   10
# 697                   Germany      Paseo          High                   10
# 698                   Germany      Paseo          High                   10
# 699  United States of America      Paseo          High                   10
#
# ...

# %%
df['Profit'] = df['Profit'].abs()
df
# Out:
#                       Country    Product Discount Band  Manufacturing Price  \
# 7                      Mexico  Carretera           Low                    3
# 8                      Mexico  Carretera           Low                    3
# 9                      France  Carretera           Low                    3
# 10                     France      Paseo           Low                   10
# 11                     Canada        VTT           Low                  250
# ..                        ...        ...           ...                  ...
# 695                    Canada      Paseo          High                   10
# 696                    Canada      Paseo          High                   10
# 697                   Germany      Paseo          High                   10
# 698                   Germany      Paseo          High                   10
# 699  United States of America      Paseo          High                   10
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%d-%b-%y')
df.dtypes
# Out:
# Country                        object
# Product                        object
# Discount Band                  object
# Manufacturing Price             int64
# Sale Price                      int64
# Discounts                     float64
# Sales                         float64
# Profit                        float64
# Date                   datetime64[ns]
# dtype: object

# %%
df.to_excel('Cleaned_book.xlsx', index = False)
